# %%
import numpy as np


import matplotlib
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt

import sys
sys.path.append('../code')
import plotter

# %% [markdown]
# ## Load and Plot MCMC Results
#
# Load the MCMC results if available (for mcmc method).

# %%
dir_configs = '../configs/configs_inference/'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0'
tag_inf = '_mcmc_nw32_nsteps5000'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference//config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps5000.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference//config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps5000.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps5000.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps5000.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (128000, 2)

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0'
tag_inf = '_mcmc_nw32_nsteps500_vary-alphaagn'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %%
plotter.plot_mcmc_fagn_lambdaagn_grid(mcmc_data)
# Out:
# Marginalized distributions:
# f_agn: mean = 0.4531, std = 0.1263, median = 0.4974
# lambda_agn: mean = 0.5066, std = 0.2759, median = 0.5160

# %% [markdown]
# this one should be biased, i put the wrong alpha_agn fixed, diff than truth! oop

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0'
tag_inf = '_mcmc_nw32_nsteps500_vary-H0'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn10_bgal1.0_bagn1.0_fagn0.5_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0'
tag_inf = '_mcmc_nw32_nsteps500_vary-H0'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0'
tag_inf = '_mcmc_nw32_nsteps500_vary-alphaagn'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-alphaagn.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %% [markdown]
# ## NSIDE64 pixelization

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0'
tag_inf = '_mcmc_nw32_nsteps500_vary-H0'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_vary-H0.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %% [markdown]
# ### Dz=0.03

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0'
tag_inf = '_mcmc_nw32_nsteps500_Dz0.03_vary-H0'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0'
tag_inf = '_mcmc_nw32_nsteps500_Dz0.03_vary-H0'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_vary-H0.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0'
tag_inf = '_mcmc_nw32_nsteps500_Dz0.03_betaH0_vary-H0'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0_vary-H0.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0_vary-H0.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0_vary-H0.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0_vary-H0.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.

# %%
dir_configs = '../configs/configs_inference'
tag_data = '_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0'
tag_inf = '_mcmc_nw32_nsteps500_Dz0.03_betaH0try2_vary-H0'
fn_config_inference = f'{dir_configs}/config_inference{tag_data}{tag_inf}.yaml'
print(fn_config_inference)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0try2_vary-H0.yaml

# %%
mcmc_data = plotter.get_mcmc_data(fn_config_inference)
plotter.plot_mcmc_contours(mcmc_data)
# Out:
# ../configs/configs_inference/config_inference_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0try2_vary-H0.yaml
# ../configs/configs_data/config_data_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0.yaml
# Loading MCMC results from: ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0try2_vary-H0.h5
# Loading inference results from ../results/inference/inference_results_seed42_ratioNgalNagn1_bgal1.0_bagn1.0_nside64_fagn0.0_lambdaagn0.0_zmaxgw1.0_mcmc_nw32_nsteps500_Dz0.03_betaH0try2_vary-H0.h5
# <KeysViewHDF5 ['lower_bound', 'mcmc_chain', 'mcmc_log_prob', 'posterior_samples', 'upper_bound']>
# Loaded MCMC results with shape: (12800, 1)
# Only 1 parameter varied; using 1D marginalized plot instead of corner.
